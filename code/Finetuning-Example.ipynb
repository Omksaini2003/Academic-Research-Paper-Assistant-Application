# %% [markdown]
# # Load your data
#
# Before finetuning a pretrained model of the experiments we provide in our repository (or precomputed and provided [here](https://datacloud.hhi.fraunhofer.de/nextcloud/s/NCjYws3mamLrkKq)), first load your custom 100 Hz sampled 12-lead ECG signal data `X` of shape `[N,L,12]` in Millivolts (mV) and multi-hot encoded labels `y` of shape `[N,C]` as numpy arrays, where `C` is the number of classes and `N` the number of total samples in this dataset. Although PTB-XL comes with fixed `L=1000` (i,e. 10 seconds), it is not required to be fixed, **BUT** the shortest sample must be longer than `input_size` of the specific model (e.g. 2.5 seconds for our fastai-models).
#
# For proper tinetuning split your data into four numpy arrays: `X_train`,`y_train`,`X_val` and `y_val`
#
# ### Example: finetune model trained on all (71) on superdiagnostic (5)
# Below we provide an example for loading [PTB-XL](https://physionet.org/content/ptb-xl/1.0.1/) aggregated at the `superdiagnostic` level, where we use the provided folds for train-validation-split:

# %%
# !git clone https://github.com/helme/ecg_ptbxl_benchmarking.git
# Out:
# Cloning into 'ecg_ptbxl_benchmarking'...
# remote: Enumerating objects: 185, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 185 (delta 64), reused 27 (delta 27), pack-reused 79 (from 2)
# Receiving objects: 100% (185/185), 46.07 MiB | 9.83 MiB/s, done.
# Resolving deltas: 100% (71/71), done.
# Updating files: 100% (51/51), done.

# %%
# %pwd
# Out:
# '/content'

# %%
# !rm -rf /ecg_ptbxl_benchmarking/data

# %%
# %cd ecg_ptbxl_benchmarking
# Out:
# /content/ecg_ptbxl_benchmarking

# %%
# !./get_datasets.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01947_lr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-06-18 16:15:20 (365 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01947_lr.hea’ saved [609/609]
#
# --2025-06-18 16:15:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01948_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01948_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:20 (1.22 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01948_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01948_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01948_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-06-18 16:15:20 (290 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01948_lr.hea’ saved [603/603]
#
# --2025-06-18 16:15:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01949_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01949_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:20 (1.31 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01949_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01949_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 611 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01949_lr.hea’
#
# physionet.org/files 100%[===================>]     611  --.-KB/s    in 0s
#
# 2025-06-18 16:15:20 (108 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01949_lr.hea’ saved [611/611]
#
# --2025-06-18 16:15:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01950_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01950_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:20 (1.21 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01950_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01950_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 616 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01950_lr.hea’
#
# physionet.org/files 100%[===================>]     616  --.-KB/s    in 0s
#
# 2025-06-18 16:15:20 (204 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01950_lr.hea’ saved [616/616]
#
# --2025-06-18 16:15:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01951_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01951_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:20 (1.26 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01951_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01951_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01951_lr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-06-18 16:15:21 (348 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01951_lr.hea’ saved [609/609]
#
# --2025-06-18 16:15:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01952_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01952_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:21 (1.29 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01952_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01952_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01952_lr.hea’
#
# physionet.org/files 100%[===================>]     608  --.-KB/s    in 0s
#
# 2025-06-18 16:15:21 (242 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01952_lr.hea’ saved [608/608]
#
# --2025-06-18 16:15:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01953_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01953_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:21 (1.16 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01953_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01953_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01953_lr.hea’
#
# physionet.org/files 100%[===================>]     608  --.-KB/s    in 0s
#
# 2025-06-18 16:15:21 (293 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01953_lr.hea’ saved [608/608]
#
# --2025-06-18 16:15:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01954_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01954_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:21 (1.21 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01954_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01954_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 612 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01954_lr.hea’
#
# physionet.org/files 100%[===================>]     612  --.-KB/s    in 0s
#
# 2025-06-18 16:15:21 (197 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01954_lr.hea’ saved [612/612]
#
# --2025-06-18 16:15:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01955_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01955_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:22 (1.17 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01955_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01955_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01955_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-06-18 16:15:22 (232 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01955_lr.hea’ saved [603/603]
#
# --2025-06-18 16:15:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01956_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01956_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:22 (1.18 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01956_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01956_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01956_lr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-06-18 16:15:22 (265 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01956_lr.hea’ saved [607/607]
#
# --2025-06-18 16:15:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01957_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01957_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:22 (1.27 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01957_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01957_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 598 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01957_lr.hea’
#
# physionet.org/files 100%[===================>]     598  --.-KB/s    in 0s
#
# 2025-06-18 16:15:22 (295 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01957_lr.hea’ saved [598/598]
#
# --2025-06-18 16:15:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01958_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01958_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:22 (1.16 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01958_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01958_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01958_lr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-06-18 16:15:22 (219 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01958_lr.hea’ saved [609/609]
#
# --2025-06-18 16:15:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01959_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01959_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:23 (1.20 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01959_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01959_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01959_lr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-06-18 16:15:23 (235 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01959_lr.hea’ saved [602/602]
#
# --2025-06-18 16:15:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01960_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01960_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:23 (1.31 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01960_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01960_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 595 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01960_lr.hea’
#
# physionet.org/files 100%[===================>]     595  --.-KB/s    in 0s
#
# 2025-06-18 16:15:23 (154 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01960_lr.hea’ saved [595/595]
#
# --2025-06-18 16:15:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01961_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01961_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:23 (1.24 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01961_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01961_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01961_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-06-18 16:15:23 (256 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01961_lr.hea’ saved [600/600]
#
# --2025-06-18 16:15:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01962_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01962_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:23 (1.21 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01962_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01962_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01962_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-06-18 16:15:23 (278 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01962_lr.hea’ saved [600/600]
#
# --2025-06-18 16:15:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01963_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01963_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:24 (1.24 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01963_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01963_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01963_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-06-18 16:15:24 (418 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01963_lr.hea’ saved [606/606]
#
# --2025-06-18 16:15:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01964_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01964_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:24 (1.20 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01964_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01964_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01964_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-06-18 16:15:24 (226 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01964_lr.hea’ saved [600/600]
#
# --2025-06-18 16:15:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01965_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01965_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:24 (1.25 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01965_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01965_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01965_lr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-06-18 16:15:24 (267 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01965_lr.hea’ saved [602/602]
#
# --2025-06-18 16:15:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01966_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01966_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:24 (1.21 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01966_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01966_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01966_lr.hea’
#
# physionet.org/files 100%[===================>]     608  --.-KB/s    in 0s
#
# 2025-06-18 16:15:24 (240 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01966_lr.hea’ saved [608/608]
#
# --2025-06-18 16:15:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01967_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01967_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:25 (1.23 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01967_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:25--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01967_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01967_lr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-06-18 16:15:25 (248 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01967_lr.hea’ saved [604/604]
#
# --2025-06-18 16:15:25--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01968_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01968_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:25 (1.17 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01968_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:25--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01968_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01968_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-06-18 16:15:25 (101 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01968_lr.hea’ saved [603/603]
#
# --2025-06-18 16:15:25--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01969_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01969_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:25 (1.15 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01969_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:25--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01969_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01969_lr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-06-18 16:15:25 (341 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01969_lr.hea’ saved [607/607]
#
# --2025-06-18 16:15:25--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01970_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01970_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:25 (1.08 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01970_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:25--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01970_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01970_lr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-06-18 16:15:26 (380 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01970_lr.hea’ saved [609/609]
#
# --2025-06-18 16:15:26--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01971_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01971_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:26 (1.19 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01971_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:26--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01971_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01971_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-06-18 16:15:26 (421 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01971_lr.hea’ saved [606/606]
#
# --2025-06-18 16:15:26--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01972_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01972_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:26 (1.37 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01972_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:26--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01972_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 611 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01972_lr.hea’
#
# physionet.org/files 100%[===================>]     611  --.-KB/s    in 0s
#
# 2025-06-18 16:15:26 (305 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01972_lr.hea’ saved [611/611]
#
# --2025-06-18 16:15:26--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01973_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01973_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:26 (1.26 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01973_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:26--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01973_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01973_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-06-18 16:15:26 (239 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01973_lr.hea’ saved [603/603]
#
# --2025-06-18 16:15:26--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01974_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01974_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:26 (1.16 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01974_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:26--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01974_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01974_lr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-06-18 16:15:27 (334 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01974_lr.hea’ saved [609/609]
#
# --2025-06-18 16:15:27--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01975_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01975_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:27 (1.16 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01975_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:27--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01975_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 598 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01975_lr.hea’
#
# physionet.org/files 100%[===================>]     598  --.-KB/s    in 0s
#
# 2025-06-18 16:15:27 (190 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01975_lr.hea’ saved [598/598]
#
# --2025-06-18 16:15:27--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01976_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01976_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:27 (1.16 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01976_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:27--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01976_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01976_lr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-06-18 16:15:27 (140 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01976_lr.hea’ saved [605/605]
#
# --2025-06-18 16:15:27--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01977_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01977_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:27 (1.25 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01977_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:27--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01977_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01977_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-06-18 16:15:27 (237 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01977_lr.hea’ saved [600/600]
#
# --2025-06-18 16:15:27--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01978_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01978_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:28 (1.22 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01978_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01978_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01978_lr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-06-18 16:15:28 (181 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01978_lr.hea’ saved [609/609]
#
# --2025-06-18 16:15:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01979_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01979_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:28 (1.43 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01979_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01979_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 614 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01979_lr.hea’
#
# physionet.org/files 100%[===================>]     614  --.-KB/s    in 0s
#
# 2025-06-18 16:15:28 (152 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01979_lr.hea’ saved [614/614]
#
# --2025-06-18 16:15:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01980_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01980_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:28 (1.22 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01980_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01980_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01980_lr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-06-18 16:15:28 (265 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01980_lr.hea’ saved [605/605]
#
# --2025-06-18 16:15:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01981_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01981_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:28 (1.36 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01981_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01981_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01981_lr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-06-18 16:15:28 (224 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01981_lr.hea’ saved [602/602]
#
# --2025-06-18 16:15:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01982_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01982_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:29 (1.29 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01982_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01982_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01982_lr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-06-18 16:15:29 (227 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01982_lr.hea’ saved [604/604]
#
# --2025-06-18 16:15:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01983_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01983_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:29 (1.27 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01983_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01983_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01983_lr.hea’
#
# physionet.org/files 100%[===================>]     608  --.-KB/s    in 0s
#
# 2025-06-18 16:15:29 (240 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01983_lr.hea’ saved [608/608]
#
# --2025-06-18 16:15:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01984_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01984_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:29 (1.22 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01984_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01984_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01984_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-06-18 16:15:29 (248 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01984_lr.hea’ saved [606/606]
#
# --2025-06-18 16:15:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01985_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01985_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:29 (1.31 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01985_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01985_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01985_lr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-06-18 16:15:29 (149 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01985_lr.hea’ saved [605/605]
#
# --2025-06-18 16:15:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01986_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01986_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:30 (1.21 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01986_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01986_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 614 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01986_lr.hea’
#
# physionet.org/files 100%[===================>]     614  --.-KB/s    in 0s
#
# 2025-06-18 16:15:30 (218 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01986_lr.hea’ saved [614/614]
#
# --2025-06-18 16:15:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01987_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01987_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:30 (1.16 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01987_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01987_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 615 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01987_lr.hea’
#
# physionet.org/files 100%[===================>]     615  --.-KB/s    in 0s
#
# 2025-06-18 16:15:30 (212 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01987_lr.hea’ saved [615/615]
#
# --2025-06-18 16:15:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01988_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01988_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:30 (1.20 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01988_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01988_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01988_lr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-06-18 16:15:30 (264 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01988_lr.hea’ saved [604/604]
#
# --2025-06-18 16:15:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01989_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01989_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:30 (1.16 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01989_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01989_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01989_lr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-06-18 16:15:30 (444 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01989_lr.hea’ saved [607/607]
#
# --2025-06-18 16:15:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01990_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01990_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:31 (1.20 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01990_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01990_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01990_lr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-06-18 16:15:31 (247 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01990_lr.hea’ saved [602/602]
#
# --2025-06-18 16:15:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01991_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01991_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:31 (1.40 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01991_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01991_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01991_lr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-06-18 16:15:31 (271 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01991_lr.hea’ saved [605/605]
#
# --2025-06-18 16:15:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01992_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01992_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:31 (1.13 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01992_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01992_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01992_lr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-06-18 16:15:31 (315 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01992_lr.hea’ saved [604/604]
#
# --2025-06-18 16:15:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01993_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01993_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:31 (1.17 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01993_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01993_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01993_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-06-18 16:15:31 (211 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01993_lr.hea’ saved [606/606]
#
# --2025-06-18 16:15:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01994_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01994_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:15:32 (1.30 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01994_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:15:32--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01994_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01994_lr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-06-18 16:15:32 (430 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/01000/01994_lr.hea’ saved [609/609]
#
# --2025-06-18 16:15:32--  https://physionet.org/files/ptb-xl/1.0.3/records100/01000/01995_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# ...
#
# 2025-06-18 16:16:20 (292 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02181_lr.hea’ saved [602/602]
#
# --2025-06-18 16:16:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02182_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02182_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:21 (1.27 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02182_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02182_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02182_lr.hea’
#
# physionet.org/files 100%[===================>]     601  --.-KB/s    in 0s
#
# 2025-06-18 16:16:21 (393 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02182_lr.hea’ saved [601/601]
#
# --2025-06-18 16:16:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02183_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02183_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:21 (1.35 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02183_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02183_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02183_lr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-06-18 16:16:21 (199 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02183_lr.hea’ saved [605/605]
#
# --2025-06-18 16:16:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02184_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02184_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:21 (1.35 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02184_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02184_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 616 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02184_lr.hea’
#
# physionet.org/files 100%[===================>]     616  --.-KB/s    in 0s
#
# 2025-06-18 16:16:21 (278 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02184_lr.hea’ saved [616/616]
#
# --2025-06-18 16:16:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02185_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02185_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:21 (1.19 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02185_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02185_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 599 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02185_lr.hea’
#
# physionet.org/files 100%[===================>]     599  --.-KB/s    in 0s
#
# 2025-06-18 16:16:21 (216 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02185_lr.hea’ saved [599/599]
#
# --2025-06-18 16:16:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02186_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02186_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:22 (1.23 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02186_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02186_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02186_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-06-18 16:16:22 (249 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02186_lr.hea’ saved [600/600]
#
# --2025-06-18 16:16:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02187_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02187_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:22 (1.25 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02187_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02187_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02187_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-06-18 16:16:22 (11.0 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02187_lr.hea’ saved [606/606]
#
# --2025-06-18 16:16:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02188_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02188_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:22 (1.24 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02188_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02188_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02188_lr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-06-18 16:16:22 (231 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02188_lr.hea’ saved [605/605]
#
# --2025-06-18 16:16:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02189_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02189_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:22 (1.23 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02189_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02189_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 614 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02189_lr.hea’
#
# physionet.org/files 100%[===================>]     614  --.-KB/s    in 0s
#
# 2025-06-18 16:16:22 (300 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02189_lr.hea’ saved [614/614]
#
# --2025-06-18 16:16:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02190_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02190_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:23 (1.20 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02190_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02190_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02190_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-06-18 16:16:23 (201 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02190_lr.hea’ saved [600/600]
#
# --2025-06-18 16:16:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02191_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02191_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:23 (1.35 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02191_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02191_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02191_lr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-06-18 16:16:23 (319 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02191_lr.hea’ saved [607/607]
#
# --2025-06-18 16:16:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02192_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02192_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:23 (1.35 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02192_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02192_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 599 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02192_lr.hea’
#
# physionet.org/files 100%[===================>]     599  --.-KB/s    in 0s
#
# 2025-06-18 16:16:23 (244 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02192_lr.hea’ saved [599/599]
#
# --2025-06-18 16:16:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02193_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02193_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:23 (1.30 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02193_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02193_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02193_lr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-06-18 16:16:23 (99.0 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02193_lr.hea’ saved [602/602]
#
# --2025-06-18 16:16:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02194_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02194_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:24 (1.26 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02194_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02194_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02194_lr.hea’
#
# physionet.org/files 100%[===================>]     601  --.-KB/s    in 0s
#
# 2025-06-18 16:16:24 (288 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02194_lr.hea’ saved [601/601]
#
# --2025-06-18 16:16:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02195_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02195_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:24 (1.19 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02195_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02195_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02195_lr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-06-18 16:16:24 (191 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02195_lr.hea’ saved [607/607]
#
# --2025-06-18 16:16:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02196_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02196_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:24 (1.21 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02196_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02196_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02196_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-06-18 16:16:24 (234 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02196_lr.hea’ saved [606/606]
#
# --2025-06-18 16:16:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02197_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02197_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-06-18 16:16:24 (1.23 MB/s) - ‘physionet.org/files/ptb-xl/1.0.3/records100/02000/02197_lr.dat’ saved [24000/24000]
#
# --2025-06-18 16:16:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/02000/02197_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... ^C

# %%
# %cd code/
# Out:
# /content/ecg_ptbxl_benchmarking/code

# %%
# !pip install wfdb
# Out:
# Collecting wfdb
#   Downloading wfdb-4.3.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.11.15)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2025.3.2)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.10.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.0.2)
# Collecting pandas>=2.2.3 (from wfdb)
#   Downloading pandas-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.32.3)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (1.15.3)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.20.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2025.4.26)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)
# Downloading wfdb-4.3.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 8.6 MB/s eta 0:00:00
# Downloading pandas-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 50.6 MB/s eta 0:00:00
# Installing collected packages: pandas, wfdb
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.0 which is incompatible.
# cudf-cu12 25.2.1 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.0 which is incompatible.
# dask-cudf-cu12 25.2.2 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.0 which is incompatible.
# Successfully installed pandas-2.3.0 wfdb-4.3.0

# %%
from utils import utils

sampling_frequency=100
datafolder='../data/physionet.org/files/ptb-xl/1.0.3'
task='superdiagnostic'
outputfolder='../output/'

# Load PTB-XL data
data, raw_labels = utils.load_dataset(datafolder, sampling_frequency)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-23-557681174> in <cell line: 0>()
#       7
#       8 # Load PTB-XL data
# ----> 9 data, raw_labels = utils.load_dataset(datafolder, sampling_frequency)
#
# /content/ecg_ptbxl_benchmarking/code/utils/utils.py in load_dataset(path, sampling_rate, release)
#     131     #     Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))
#     132
# --> 133         # Load raw signal data
#     134         # X = load_raw_data_icbeb(Y, sampling_rate, path)
#     135     X=2
#
# UnboundLocalError: cannot access local variable 'X' where it is not associated with a value

# %%
# Preprocess label data
labels = utils.compute_label_aggregations(raw_labels, datafolder, task)
# Select relevant data and convert to one-hot
data, labels, Y, _ = utils.select_data(data, labels, task, min_samples=0, outputfolder=outputfolder)

# 1-9 for training
X_train = data[labels.strat_fold < 10]
y_train = Y[labels.strat_fold < 10]
# 10 for validation
X_val = data[labels.strat_fold == 10]
y_val = Y[labels.strat_fold == 10]

num_classes = 5         # <=== number of classes in the finetuning dataset
input_shape = [1000,12] # <=== shape of samples, [None, 12] in case of different lengths

X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-19-1330752767> in <cell line: 0>()
#       7
#       8 # Load PTB-XL data
# ----> 9 data, raw_labels = utils.load_dataset(datafolder, sampling_frequency)
#      10 # Preprocess label data
#      11 labels = utils.compute_label_aggregations(raw_labels, datafolder, task)
#
# /content/ecg_ptbxl_benchmarking/code/utils/utils.py in load_dataset(path, sampling_rate, release)
#     131
#     132         # Load raw signal data
# --> 133         # X = load_raw_data_icbeb(Y, sampling_rate, path)
#     134
#     135     return X, Y
#
# UnboundLocalError: cannot access local variable 'X' where it is not associated with a value

# %% [markdown]
# # Train or download models
# There are two possibilities:
#    1. Run the experiments as described in README. Afterwards you find trained in models in `output/expX/models/`
#    2. Download the precomputed `output`-folder with all experiments and models from [here]((https://datacloud.hhi.fraunhofer.de/nextcloud/s/NCjYws3mamLrkKq))
#
# # Load pretrained model
#
# For loading a pretrained model:
#    1. specify `modelname` which can be seen in `code/configs/` (e.g. `modelname='fastai_xresnet1d101'`)
#    2. provide `experiment` to build the path `pretrainedfolder` (here: `exp0` refers to the experiment with `all` 71 SCP-statements)
#
# This returns the pretrained model where the classification is replaced by a random initialized head with the same number of outputs as the number of classes.

# %%
from models.fastai_model import fastai_model

experiment = 'exp0'
modelname = 'fastai_xresnet1d101'
pretrainedfolder = '../output/'+experiment+'/models/'+modelname+'/'
mpath='../output/' # <=== path where the finetuned model will be stored
n_classes_pretrained = 71 # <=== because we load the model from exp0, this should be fixed because this depends the experiment

model = fastai_model(
    modelname,
    num_classes,
    sampling_frequency,
    mpath,
    input_shape=input_shape,
    pretrainedfolder=pretrainedfolder,
    n_classes_pretrained=n_classes_pretrained,
    pretrained=True,
    epochs_finetuning=2,
)

# %% [markdown]
# # Preprocess data with pretrained Standardizer
#
# Since we standardize inputs to zero mean and unit variance, your custom data needs to be standardized with the respective mean and variance. This is also provided in the respective experiment folder `output/expX/data/standard_scaler.pkl`

# %%
import pickle

standard_scaler = pickle.load(open('../output/'+experiment+'/data/standard_scaler.pkl', "rb"))

X_train = utils.apply_standardizer(X_train, standard_scaler)
X_val = utils.apply_standardizer(X_val, standard_scaler)
# Out:
# /home/wagner/anaconda3/envs/ecg_python37/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.preprocessing.data module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.preprocessing. Anything that cannot be imported from sklearn.preprocessing is now part of the private API.
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-5fe1be60124f> in <module>
#       3 standard_scaler = pickle.load(open('../output/'+experiment+'/data/standard_scaler.pkl', "rb"))
#       4
# ----> 5 X_train = utils.apply_standardizer(X_train, standard_scaler)
#       6 X_val = utils.apply_standardizer(X_val, standard_scaler)
#
# ~/github/ecg_ptbxl_benchmarking/code/utils/utils.py in apply_standardizer(X, ss)
#     329     for x in X:
#     330         x_shape = x.shape
# --> 331         X_tmp.append(ss.transform(x.flatten()[:,np.newaxis]).reshape(x_shape))
#     332     X_tmp = np.array(X_tmp)
#     333     return X_tmp
#
# ~/anaconda3/envs/ecg_python37/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#     792                                 accept_sparse='csr', copy=copy,
#     793                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 794                                 force_all_finite='allow-nan')
#     795
#     796         if sparse.issparse(X):
#
# ~/anaconda3/envs/ecg_python37/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     434
#     435         if check_params.get('ensure_2d', True):
# --> 436             self._check_n_features(X, reset=reset)
#     437
#     438         return out
#
# ~/anaconda3/envs/ecg_python37/lib/python3.7/site-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     371             if not hasattr(self, 'n_features_in_'):
#     372                 raise RuntimeError(
# --> 373                     "The reset parameter is False but there is no "
#     374                     "n_features_in_ attribute. Is this estimator fitted?"
#     375                 )
#
# RuntimeError: The reset parameter is False but there is no n_features_in_ attribute. Is this estimator fitted?

# %% [markdown]
# # Finetune model
#
# Calling `model.fit` of a model with `pretrained=True` will perform finetuning as proposed in our work i.e. **gradual unfreezing and discriminative learning rates**.

# %%
model.fit(X_train, y_train, X_val, y_val)
# Out:
# Finetuning...
# model: fastai_xresnet1d101
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.271710</td>
#       <td>0.271859</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.237324</td>
#       <td>0.268521</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.230869</td>
#       <td>0.270421</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.230395</td>
#       <td>0.268627</td>
#       <td>00:33</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Evaluate model on validation data

# %%
y_val_pred = model.predict(X_val)
utils.evaluate_experiment(y_val, y_val_pred)
# Out:
# aggregating predictions...
#    macro_auc      Fmax
# 0   0.931458  0.827961
